# %%
import json

# %% [markdown]
# # YFinance

# %%
import yfinance as yf

# %%
dat = yf.Ticker('OUI')

# %%
type(dat.info)
# Out:
# dict

# %%
dat.info
# Out:
# {'exchange': 'YHD',
#  'quoteType': 'MUTUALFUND',
#  'symbol': 'OUI',
#  'underlyingSymbol': 'OUI',
#  'shortName': '3264',
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '57a15e3f-e935-3f2f-a047-27b2176670e2',
#  'gmtOffSetMilliseconds': -18000000,
#  'maxAge': 86400,
#  'trailingPegRatio': None}

# %%
len(dat.info)
# Out:
# 12

# %%
dat = yf.Ticker('MSFT')

# %%
dat.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
dat.info['longName']
# Out:
# 'Microsoft Corporation'

# %%
dat.calendar
# Out:
# {'Dividend Date': datetime.date(2025, 3, 12),
#  'Ex-Dividend Date': datetime.date(2025, 2, 19),
#  'Earnings Date': [datetime.date(2025, 1, 28), datetime.date(2025, 2, 3)],
#  'Earnings High': 3.47,
#  'Earnings Low': 3.02,
#  'Earnings Average': 3.1393,
#  'Revenue High': 70520000000,
#  'Revenue Low': 68488700000,
#  'Revenue Average': 68872073750}

# %% [markdown]
# # Web Parsing

# %% [markdown]
# # Finnhub

# %%
import finnhub

# %%
finnhub_client = finnhub.Client(api_key='cttk5u9r01qqhvb0prj0cttk5u9r01qqhvb0prjg')

# %%
us_stocks = finnhub_client.stock_symbols(exchange='US', mic='XASE')

# %%
print(len(us_stocks))
# Out:
# 325

# %%
us_stocks[0:2]
# Out:
# [{'currency': 'USD',
#   'description': 'TRIUMPH GROUP INC',
#   'displaySymbol': 'TGI',
#   'figi': 'BBG000BM7L13',
#   'isin': None,
#   'mic': 'XNYS',
#   'shareClassFIGI': 'BBG001S6MWK6',
#   'symbol': 'TGI',
#   'symbol2': '',
#   'type': 'Common Stock'},
#  {'currency': 'USD',
#   'description': 'VOYA FINANCIAL INC',
#   'displaySymbol': 'VOYA',
#   'figi': 'BBG000BCWKD6',
#   'isin': None,
#   'mic': 'XNYS',
#   'shareClassFIGI': 'BBG001S6QQP0',
#   'symbol': 'VOYA',
#   'symbol2': '',
#   'type': 'Common Stock'}]

# %%
tickers = {company['displaySymbol']: company['description'] for company in us_stocks}

# %%
len(tickers)
# Out:
# 2910

# %%
print(tickers)
# Out:
# {'TGI': 'TRIUMPH GROUP INC', 'VOYA': 'VOYA FINANCIAL INC', 'AHT.PRH': 'ASHFORD HOSPITALITY TRUS - AHT 7 1/2 PERP', 'CPK': 'CHESAPEAKE UTILITIES CORP', 'CMSA': 'CMS ENERGY CORP - CMS 5 5/8 03/15/2078', 'NOW': 'SERVICENOW INC', 'MPW': 'MEDICAL PROPERTIES TRUST INC', 'MYN': 'BLACKROCK MUNIYIELD NY QLTY', 'PKX': 'POSCO HOLDINGS INC -SPON ADR', 'MPLN': 'MULTIPLAN CORP', 'SHAP.WS': 'Spree Acquisition Corp 1 Limited', 'MCI': 'BARINGS CORPORATE INVESTORS', 'EVEX.WS': 'EVE HOLDNG INC -CW25', 'EDN': 'EMP DISTRIB Y COMERC NOR-ADR', 'AMCR': 'AMCOR PLC', 'GLP': 'GLOBAL PARTNERS LP', 'OHI': 'OMEGA HEALTHCARE INVESTORS', 'MTR': 'MESA ROYALTY TRUST', 'BGY': 'BLACKROCK ENH INTL DVD TR', 'EARN': 'ELLINGTON CREDIT CO', 'SSD': 'SIMPSON MANUFACTURING CO INC', 'K': 'KELLANOVA', 'NPKI': 'NPK INTERNATIONAL INC', 'SREA': 'SEMPRA - SRE 5 3/4 07/01/2079', 'GDDY': 'GODADDY INC - CLASS A', 'KEYS': 'KEYSIGHT TECHNOLOGIES IN', 'WPM': 'WHEATON PRECIOUS METALS CORP', 'BDC': 'BELDEN INC', 'ETY': 'EATON VANCE TAX-MGD 
# ...

# %%
print(json.dumps({'result': tickers}))
# Out:
# {"result": {"TGI": "TRIUMPH GROUP INC", "VOYA": "VOYA FINANCIAL INC", "AHT.PRH": "ASHFORD HOSPITALITY TRUS - AHT 7 1/2 PERP", "CPK": "CHESAPEAKE UTILITIES CORP", "CMSA": "CMS ENERGY CORP - CMS 5 5/8 03/15/2078", "NOW": "SERVICENOW INC", "MPW": "MEDICAL PROPERTIES TRUST INC", "MYN": "BLACKROCK MUNIYIELD NY QLTY", "PKX": "POSCO HOLDINGS INC -SPON ADR", "MPLN": "MULTIPLAN CORP", "SHAP.WS": "Spree Acquisition Corp 1 Limited", "MCI": "BARINGS CORPORATE INVESTORS", "EVEX.WS": "EVE HOLDNG INC -CW25", "EDN": "EMP DISTRIB Y COMERC NOR-ADR", "AMCR": "AMCOR PLC", "GLP": "GLOBAL PARTNERS LP", "OHI": "OMEGA HEALTHCARE INVESTORS", "MTR": "MESA ROYALTY TRUST", "BGY": "BLACKROCK ENH INTL DVD TR", "EARN": "ELLINGTON CREDIT CO", "SSD": "SIMPSON MANUFACTURING CO INC", "K": "KELLANOVA", "NPKI": "NPK INTERNATIONAL INC", "SREA": "SEMPRA - SRE 5 3/4 07/01/2079", "GDDY": "GODADDY INC - CLASS A", "KEYS": "KEYSIGHT TECHNOLOGIES IN", "WPM": "WHEATON PRECIOUS METALS CORP", "BDC": "BELDEN INC", "ETY": "EATON VAN
# ...

# %% [markdown]
# # Symbol API

# %%
from urllib.request import urlopen
import certifi
import json

# %%
url = ("https://financialmodelingprep.com/api/v3/search-ticker?query=AA&limit=30&exchange=NASDAQ&apikey=fUnFc1JqkGKPMlZ7eH3OGfNZ4tUqivw1")

# %%
response = urlopen(url, cafile=certifi.where())
data = response.read().decode('utf-8')
# Out:
# C:\Users\MohitSoni\AppData\Local\Temp\ipykernel_26732\3563615438.py:1: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())

# %%
tickerData = json.loads(data)

# %%
print(len(tickerData))
# Out:
# 30

# %%
print(json.dumps(tickerData, indent=4))
# Out:
# [
#     {
#         "symbol": "AAL",
#         "name": "American Airlines Group Inc.",
#         "currency": "USD",
#         "stockExchange": "NASDAQ Global Select",
#         "exchangeShortName": "NASDAQ"
#     },
#     {
#         "symbol": "AAXJ",
#         "name": "iShares MSCI All Country Asia ex Japan ETF",
#         "currency": "USD",
#         "stockExchange": "NASDAQ Global Market",
#         "exchangeShortName": "NASDAQ"
#     },
#     {
#         "symbol": "AAWW",
#         "name": "Atlas Air Worldwide Holdings, Inc.",
#         "currency": "USD",
#         "stockExchange": "NASDAQ Global Select",
#         "exchangeShortName": "NASDAQ"
#     },
#     {
#         "symbol": "AAPU",
#         "name": "Direxion Daily AAPL Bull 1.5X Shares",
#         "currency": "USD",
#         "stockExchange": "NASDAQ Global Market",
#         "exchangeShortName": "NASDAQ"
#     },
#     {
#         "symbol": "AAPL",
#         "name": "Apple Inc.",
#         "currency": "USD",
# ...
